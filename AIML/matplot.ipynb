# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.show()

# %%
interval_x = np.linspace(0,20,50)
test_datay = interval_x # x = y
square_teestData = interval_x**2 # y = x**2
cube_data = interval_x**3 # y = x3

# plotting the data.

# %%
# ploting data
plt.plot(interval_x,test_datay)
plt.show()
interval_x.shape
# Out:
# (50,)

# %% [markdown]
# ### Changing colour of plot

# %%
plt.plot(interval_x,test_datay,"g") # giving g argument for green colour of line.

# %%
#using dark background
plt.style.use("dark_background")
# print(plt.style.available) # To check all style we can use.
# Change colour of plot
plt.plot(interval_x,test_datay,"w")

# %% [markdown]
# #### Labelling axis and plot.

# %%
plt.style.use("default")
plt.plot(interval_x,test_datay,"r")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Linear Graph")
# Out:
# Text(0.5, 1.0, 'Linear Graph')

# %% [markdown]
# #### Changing Size of figure

# %%
plt.rcParams["figure.figsize"] = 6,4
plt.plot(interval_x,test_datay,"r")

# %%
plt.plot(interval_x,test_datay,'y',linewidth=5)

# %%
plt.plot(interval_x,test_datay,'y',linestyle="dotted")

# %%
plt.plot(interval_x,test_datay,'y',linestyle='dashed')

# %%
plt.plot(interval_x,test_datay,'y',linestyle='dashdot')

# %% [markdown]
# ## MArker type and marker size

# %%
plt.plot(interval_x,test_datay,'g*',markersize=10)

# %%
plt.plot(interval_x,test_datay,'go',markersize=4)

# %% [markdown]
# #### Multiple plots

# %%
# plt.subplot(nrow,ncolumn,index)
plt.subplot(2,1,1)
plt.plot(interval_x,square_teestData,'g-',markersize=7)
plt.xlabel('X axis')
plt.ylabel("Y axis")
plt.title("Square")

plt.subplots_adjust(hspace=1)

plt.subplot(2,1,2)
plt.plot(interval_x,cube_data,'r-',markersize=7)
plt.xlabel("X axis")
plt.title("cubic")
# Out:
# Text(0.5, 1.0, 'cubic')

# %% [markdown]
# ### legend

# %%
# plt.subplot(nrow,ncolumn,index)
plt.subplot(1,2,1)
plt.plot(interval_x,square_teestData,'g-.',markersize=7,label="square")
plt.xlabel('X axis')
plt.ylabel("Y axis")
plt.title("Square")

plt.subplots_adjust(wspace=1) # Vertical space for figures.

plt.subplot(1,2,2)
plt.plot(interval_x,cube_data,'r-.',markersize=7,label='cube')
plt.xlabel("X axis")
plt.title("cubic")
# Out:
# Text(0.5, 1.0, 'cubic')

# %%
 # plt.text(xpos,ypos,"Text",fontsize)
 plt.plot(interval_x,test_datay,'y',label='Mk')
 plt.text(0,11,'Monu',fontsize=20)
# Out:
# Text(0, 11, 'Monu')

# %%
 plt.plot(interval_x,test_datay,'y',label='Mk')

plt.xlim(0,30)
plt.ylim(0,30)
# Out:
# (0.0, 30.0)

# %% [markdown]
# ### Example Showing Various Line Types and Marker Types

# %%
x = np.linspace(0, 5, 10)
y = x ** 2


fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="blue", linewidth=0.25)
ax.plot(x, x+2, color="blue", linewidth=0.50)
ax.plot(x, x+3, color="blue", linewidth=1.00)
ax.plot(x, x+4, color="blue", linewidth=2.00)

# possible linestype options ‘-‘, ‘--’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="red", lw=2, linestyle='-')
ax.plot(x, x+6, color="red", lw=2, ls='-.')
ax.plot(x, x+7, color="red", lw=2, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="green", lw=2, ls='--', marker='+')
ax.plot(x, x+10, color="green", lw=2, ls='--', marker='o')
ax.plot(x, x+11, color="green", lw=2, ls='--', marker='s')
ax.plot(x, x+12, color="green", lw=2, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=2, markeredgecolor="blue")
